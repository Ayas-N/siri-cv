# %%
import os
import ultralytics
from ultralytics import YOLO

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /home/its-joji/Documents/yolov8_synthetic_run/src

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.12.2 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Setup complete ✅ (16 CPUs, 14.9 GB RAM, 78.0/114.0 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/home/its-joji/Documents/yolov8_synthetic_run/coco_data/coco_data.yaml epochs=50 imgsz=640 batch=8 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.86 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75 🚀 Python-3.12.2 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# ...

# %%
# !yolo val model=/home/its-joji/Documents/yolov8_synthetic_run/src/runs/detect/train6/weights/best.pt data=/home/its-joji/Documents/yolov8_synthetic_run/coco_data/coco_data.yaml task=detect
# Out:
# Ultralytics 8.3.75 🚀 Python-3.12.2 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/its-joji/Documents/yolov8_synthetic_run/coco_data/labels/val
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        100         97      0.416      0.515       0.45      0.355
# Speed: 1.8ms preprocess, 19.6ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/detect/val5
# 💡 Learn more at https://docs.ultralytics.com/modes/val
